# %% [markdown]
# ## ShopSmart Analytics
# A Python analytics script for ShopSmart to help them answer various questions from their data
#
# #### Section 1: Data types (Building Blocks)

# %%
#core data types
#int
#str
#bool
#float

customer_id = 1001
customer_age = 34
loyalty_points = 520

### 
average_purchase = 15750.50
discount_rate = 0.15
wallet_balance = 5200.75

#String variables
customer_name = "Peace Philip"
membership_type = 'Premium'
email = 'amara.okafor@gmail.com'


#Boolean simple means TRUE or FALSE (please note that for Boolean, your True or False must start with a capital T or F 
is_active = True
has_voucher = False

print(customer_id)
print(customer_age, loyalty_points)
print("Customer ID:", customer_id)
print("Customer Age:", customer_age, "Loyalty Points:", loyalty_points)
# Out:
# 1001
# 34 520
# Customer ID: 1001
# Customer Age: 34 Loyalty Points: 520

# %%
# whenever a string sees +, it concatenates or joins not add. 
#e.g
age = "34" + "25"
print(age)
# Out:
# 3425

# %%
#to actually add, you need to convert 34 and 25 from string to integers
age = int('34') + int('25')
print(age)
# Out:
# 59

# %%
#F string for print formatting, with print formatting, your variable goes in a {}
print(f"Customer ID {customer_id}")
print(f"Discount Rate: {discount_rate:>10,.2f}")
# Out:
# Customer ID 1001
# Discount Rate:       0.15

# %% [markdown]
# ## Data Structures in Python
# - Dictionary
# - List
# - Tuples
# - Set

# %%
#Python List (an ordered collection of items that is changeable. ot is created using square brackets [])

#Purchase History
johnson_purchase = [15000, 8500, 22000.0, 3000]
smith = [3200, 4100, 2800.00, 6700.00]

#Indexing is a way to specify what item within a list you need. Python starts counting from 0, so to get the first item in a list you use [0]
johnson_purchase[0]
# Out:
# 15000

# %%
#counting can also be done from behing using [-1]
johnson_purchase[-1]
# Out:
# 3000

# %%
print(f"Johnson's first purchase was {johnson_purchase[0]}.")
print(f"Johnson's last purchase was {johnson_purchase[-1]}.")
# Out:
# Johnson's first purchase was 15000.
# Johnson's last purchase was 3000.

# %%
#Slicing
#Johnson first and second purchase

johnson_purchase[0:2]
# Out:
# [15000, 8500]

# %%
#last two purchases

johnson_purchase[-2:]
# Out:
# [22000.0, 3000]

# %%
johnson_purchase[:]
# Out:
# [15000, 8500, 22000.0, 3000]
